# %% [markdown]
# ---
# title: Geometric Distortions Notebook
# authors: [gvarnavides]
# date: 2026-05-28
# ---

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from aberration_utils import AberrationsWidget

plt.rcParams['text.color']='white'
plt.rcParams['xtick.labelcolor'] = 'white'
plt.rcParams['xtick.color'] = 'white'
plt.rcParams['ytick.labelcolor'] = 'white'
plt.rcParams['ytick.color'] = 'white'
plt.rcParams['axes.labelcolor'] = 'white'
plt.rcParams['axes.edgecolor'] = 'white'
plt.rcParams.update({
    "text.usetex": True,
    "text.latex.preamble": r"\usepackage{amsmath}"
})

# %%
#| label: app:geometric_aberrations_widget
viz = AberrationsWidget(
    energy=300e3,
    gpts=(512, 512),
    sampling=(0.1, 0.1),
    n_blocks=16,
    quiver_step=32,
).display()
viz
# Out:
# VBox(children=(VBox(children=(HBox(children=(FloatSlider(value=0.0, description='$C_{10}$ (Å)', layout=Layout(…
